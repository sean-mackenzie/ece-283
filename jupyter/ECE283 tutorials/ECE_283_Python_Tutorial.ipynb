# %%
#basic operations
x = 3 #setting variable
y = x + 5 #addition
print("x + 3 =", y)  #print statement
# Out:
# x + 3 = 8

# %%
a = 3 - 2 #subtraction
print(a)
b = 4*2 #multiplication
print(b)
c = 5/2 #division
print(c)
# Out:
# 1
# 8
# 2.5

# %%
#logical operators
5 == 4 #equivalence
# Out:
# False

# %%
5 > 4 #greater than
# Out:
# True

# %%
#types
type("hello") #string type
# Out:
# str

# %%
type(5)#integer type
# Out:
# int

# %%
#lists
list_example = [1, 2, 3, 'Apple', 'orange', 2]
print(list_example[0])
print(list_example[-1])
print(len(list_example))
# Out:
# 1
# 2
# 6

# %%
list_example.append("test_append") #list append
list_example
# Out:
# [1, 2, 3, 'Apple', 'orange', 2, 'test_append']

# %%
#dictionaries
dict_1 = {'apple':3, 'orange':4, 'pear':2}
dict_1['pear']
# Out:
# 2

# %%
dict_a = {"One":1, "Two":2, "Three":3}

for key in dict_a.keys(): #accessing dictionary key/values
    print(key, dict_a[key])
# Out:
# One 1
# Two 2
# Three 3

# %%
#numpy arrays
import numpy as np 
x = np.array([1, 4, 3])
x
np.shape(x)
# Out:
# (3,)

# %%
#numpy matrix
y = np.array([[1, 4, 3], [9, 2, 7]])
print(y)
print(y[0,1])
print(y[1, :])
# Out:
# [[1 4 3]
#  [9 2 7]]
# 4
# [9 2 7]

# %%
y.shape
# Out:
# (2, 3)

# %%
np.arange(0.5, 3, 0.5) #np.arange(start, end, increment)
# Out:
# array([0.5, 1. , 1.5, 2. , 2.5])

# %%
int_zeros = np.zeros((3, 1))
int_zeros.shape
# Out:
# (3, 1)

# %%
#assigning array values
b = np.zeros((2, 2))
b[0, 0] = 1
b[0, 1] = 2
b[1, 0] = 3
b[1, 1] = 4
b
# Out:
# array([[1., 2.],
#        [3., 4.]])

# %%
b**2 #multiplies each element by 2, element-wise addition, subtraction, division, and exponentiation can be done similarly
# Out:
# array([[ 1.,  4.],
#        [ 9., 16.]])

# %%
b.T #transpose
# Out:
# array([[1., 3.],
#        [2., 4.]])

# %%
#numpy matrices, matrix multiplication
x = np.array([[1, 2], [3, 4]])
y = np.array([[1, 4, 3], [9, 2, 7]])
z = np.matmul(x,y) #can also do x @ y
print(z)
# Out:
# [[19  8 17]
#  [39 20 37]]

# %%
#function example
def my_adder(a, b, c):
    """
    function to sum the 3 numbers
    Input: 3 numbers a, b, c
    Output: the sum of a, b, and c
    author:
    date:
    """
    out = a + b + c
    
    return out

# %%
d = my_adder(1, 2, 3)
d
# Out:
# 6

# %%
#function example, branch statements
def my_thermo_stat(temp, desired_temp):
    """
    Changes the status of the thermostat based on 
    temperature and desired temperature
    author
    date
    :type temp: Int
    :type desiredTemp: Int
    :rtype: String
    """
    if temp < desired_temp - 5:
        status = 'Heat'
    elif temp > desired_temp + 5:
        status = 'AC'
    else:
        status = 'off'
    return status

# %%
status = my_thermo_stat(65,75)
print(status)
# Out:
# Heat

# %%
#for loop
n = 0
for i in range(1, 4):
    n = n + i
    
print(n)
# Out:
# 6

# %%
#solving Ax = y
import numpy as np

A = np.array([[4, 3, -5], 
              [-2, -4, 5], 
              [8, 8, 0]])
y = np.array([2, 5, -3])

x = np.linalg.solve(A, y)
print(x)
# Out:
# [ 2.20833333 -2.58333333 -0.18333333]

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
x = [0, 1, 2, 3] 
y = [0, 1, 4, 9]
plt.figure(0)
plt.plot(x, y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mean = [0, 0]
cov = [[1, 0], [0, 100]]  # diagonal covariance

x, y = np.random.multivariate_normal(mean, cov, 5000).T
plt.figure(1)
plt.plot(x, y, 'x')
plt.axis('equal')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#scatter plot function
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.figure(2)
plt.scatter(x, y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
